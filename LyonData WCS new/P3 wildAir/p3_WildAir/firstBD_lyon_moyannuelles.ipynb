# %%
import pandas as pd

firstDB = pd.read_csv(r"C:\Users\sophi\OneDrive\Documentos\LyonData formação\#Projetos de Grupo\P3 wildAir\p3_WildAir\Concentrations_moyennes_annuelles.csv", sep=",", skipinitialspace=True)

# %%
firstDB.head()
# Out:
#                X             Y nom_dept nom_com  id_com  \
# 0  742032.459854  5.653151e+06   Savoie  Modane   73157
# 1  742032.459854  5.653151e+06   Savoie  Modane   73157
# 2  535486.491774  5.671063e+06    Isère  Chanas   38072
# 3  538445.543196  5.743964e+06    Rhône    Lyon   69123
# 4  538445.543196  5.743964e+06    Rhône    Lyon   69123
#
#                date_debut                date_fin  \
# 0  2021/01/01 00:00:00+00  2022/01/01 00:00:00+00
# 1  2022/01/01 00:00:00+00  2023/01/01 00:00:00+00
# 2  2023/01/01 00:00:00+00  2024/01/01 00:00:00+00
# 3  2019/01/01 00:00:00+00  2020/01/01 00:00:00+00
# 4  2020/01/01 00:00:00+00  2021/01/01 00:00:00+00
#
#                              nom_station code_station               typologie  \
# 0                         Modane Piscine      ET00697                  Urbain
# 1                         Modane Piscine      ET00697                  Urbain
# 2                             Sud Chanas      ET00818  Observation Spécifique
# ...

# %%
df_lyon = firstDB[firstDB["nom_com"] == "Lyon"]
df_lyon.head()
# Out:
#                X             Y nom_dept nom_com  id_com  \
# 3  538445.543196  5.743964e+06    Rhône    Lyon   69123
# 4  538445.543196  5.743964e+06    Rhône    Lyon   69123
# 5  538445.543196  5.743964e+06    Rhône    Lyon   69123
# 6  538445.543196  5.743964e+06    Rhône    Lyon   69123
# 7  538445.543196  5.743964e+06    Rhône    Lyon   69123
#
#                date_debut                date_fin  \
# 3  2019/01/01 00:00:00+00  2020/01/01 00:00:00+00
# 4  2020/01/01 00:00:00+00  2021/01/01 00:00:00+00
# 5  2021/01/01 00:00:00+00  2022/01/01 00:00:00+00
# 6  2022/01/01 00:00:00+00  2023/01/01 00:00:00+00
# 7  2023/01/01 00:00:00+00  2024/01/01 00:00:00+00
#
#                              nom_station code_station typologie  ...  \
# 3  Lyon Tunnel Croix-Rousse Sortie Rhône      ET00906    Urbain  ...
# 4  Lyon Tunnel Croix-Rousse Sortie Rhône      ET00906    Urbain  ...
# 5  Lyon Tunnel Croix-Rousse Sortie Rhône      ET00906    Urbain  ...
# ...

# %%
df_lyon.describe()
# Out:
#                    X             Y   id_com  id_poll_ue     valeur  \
# count      20.000000  2.000000e+01     20.0        20.0  20.000000
# mean   538935.028168  5.740986e+06  69123.0         8.0  27.415000
# std      1034.062802  2.202602e+03      0.0         0.0  13.418851
# min    537650.229844  5.738031e+06  69123.0         8.0   0.000000
# 25%    538246.714858  5.739754e+06  69123.0         8.0  20.550000
# 50%    538860.236455  5.740974e+06  69123.0         8.0  25.350000
# 75%    539548.549765  5.742206e+06  69123.0         8.0  32.100000
# max    540369.409918  5.743964e+06  69123.0         8.0  65.000000
#
#                yl93           xl93    OBJECTID
# count  2.000000e+01      20.000000   20.000000
# mean   6.518804e+06  843130.888207  126.250000
# std    1.538680e+03     710.276573   73.374938
# min    6.516726e+06  842281.625000    4.000000
# 25%    6.517946e+06  842626.156250  104.750000
# 50%    6.518811e+06  843059.968750  157.000000
# ...
