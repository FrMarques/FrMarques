# %%
import pandas as pd

geodair69test = pd.read_csv(r"C:\Users\sophi\OneDrive\Documentos\LyonData formação\#Projetos de Grupo\P3 wildAir\p3_WildAir\DECADQ_69_previous-1950-2023.csv", sep=";")

geodair69test.head(3)
# Out:
#    NUM_POSTE        NOM_USUEL        LAT       LON  ALTI  AAAAMM  NUM_DECADE  \
# 0   69006001  AMPLEPUIS BOURG  45.971667  4.331667   435  196303           1
# 1   69006001  AMPLEPUIS BOURG  45.971667  4.331667   435  196303           2
# 2   69006001  AMPLEPUIS BOURG  45.971667  4.331667   435  196303           3
#
#      RR  QRR  NBRR  ...  QNEIGETOTM  NEIGETOTAB  QNEIGETOTAB  NEIGETOTABDAT  \
# 0   7.6  1.0    10  ...         NaN         NaN          NaN            NaN
# 1  33.9  1.0    10  ...         NaN         NaN          NaN            NaN
# 2  33.9  1.0    11  ...         NaN         NaN          NaN            NaN
#
#    NBJNEIGETOT1  NBJNEIGETOT10  NBJNEIGETOT30  NBJGREL  NBJORAG  NBJBROU
# 0           NaN            NaN            NaN      NaN      NaN      NaN
# 1           NaN            NaN            NaN      NaN      NaN      NaN
# 2           NaN            NaN            NaN      NaN      NaN      NaN
#
# [3 rows x 158 columns]

# %%
geodair69test.shape
# Out:
# (122948, 158)
